# %%
import pandas as pd

# %%
us_election = pd.read_csv(r"C:\Users\MANPREET\Desktop\election 2020.csv")

# %%
us_election
# Out:
#                    state state_abr  trump_pct  biden_pct  trump_vote  \
# 0                 Alaska        AK       53.1       43.0      189543
# 1                 Hawaii        HI       34.3       63.7      196864
# 2             Washington        WA       39.0       58.4     1584651
# 3                 Oregon        OR       40.7       56.9      958448
# 4             California        CA       34.3       63.5     5982194
# 5                  Idaho        ID       63.9       33.1      554128
# 6                Montana        MT       56.9       40.6      343647
# 7                 Nevada        NV       47.7       50.1      669890
# 8                Wyoming        WY       70.4       26.7      193559
# 9                   Utah        UT       58.2       37.7      865140
# 10               Arizona        AZ       49.1       49.4     1661686
# 11              Colorado        CO       41.9       55.4     1364471
# 12            New Mexico        NM       43.5       54.3      401894
# ...

# %%
us_election.shape
# Out:
# (51, 8)

# %%
us_election.head(2)
# Out:
#     state state_abr  trump_pct  biden_pct  trump_vote  biden_vote  trump_win  \
# 0  Alaska        AK       53.1       43.0      189543      153502          1
# 1  Hawaii        HI       34.3       63.7      196864      366130          0
#
#    biden_win
# 0          0
# 1          1
